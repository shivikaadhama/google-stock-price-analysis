# %%
# !pip install pandas numpy matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_excel('../data/google.xlsx')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_excel('../data/google.xlsx')
#       3 df.head()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
# ...

# %%
df = pd.read_csv('data/google.csv')

df.head()
# Out:
#          Date      Open         High          Low     Close  Adj Close  \
# 0  2004-08-19  2.490664  2.591784954  2.390042067  2.499133   2.499133
# 1  2004-08-20  2.515820  2.716816902  2.503118038  2.697639   2.697639
# 2  2004-08-23  2.758411  2.826406002  2.716069937  2.724787   2.724787
# 3  2004-08-24  2.770615   2.77958107  2.579581022  2.611960   2.611960
# 4  2004-08-25  2.614201  2.689918041   2.58730197  2.640104   2.640104
#
#       Volume
# 0  897427216
# 1  458857488
# 2  366857939
# 3  306396159
# 4  184645512

# %%
df.shape
# Out:
# (4842, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4842 entries, 0 to 4841
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4842 non-null   str
#  1   Open       4842 non-null   float64
#  2   High       4842 non-null   str
#  3   Low        4842 non-null   str
#  4   Close      4842 non-null   float64
#  5   Adj Close  4842 non-null   float64
#  6   Volume     4842 non-null   int64
# dtypes: float64(3), int64(1), str(3)
# memory usage: 264.9 KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

df['High'] = pd.to_numeric(df['High'], errors='coerce')
df['Low'] = pd.to_numeric(df['Low'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4842 entries, 0 to 4841
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4842 non-null   datetime64[us]
#  1   Open       4842 non-null   float64
#  2   High       4841 non-null   float64
#  3   Low        4839 non-null   float64
#  4   Close      4842 non-null   float64
#  5   Adj Close  4842 non-null   float64
#  6   Volume     4842 non-null   int64
# dtypes: datetime64[us](1), float64(5), int64(1)
# memory usage: 264.9 KB

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4838, 7)

# %%
df = df.sort_values('Date')

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.499133  897427216
# 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.697639  458857488
# 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.724787  366857939
# 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.611960  306396159
# 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.640104  184645512

# %%
plt.figure(figsize=(12,6))

plt.plot(df['Close'])

plt.title("Google Stock Closing Price Over Time")
plt.xlabel("Year")
plt.ylabel("Stock Price")

plt.savefig('images/price_trend.png')

plt.show()

# %%
df['MA50'] = df['Close'].rolling(window=50).mean()
df['MA200'] = df['Close'].rolling(window=200).mean()

# %%
plt.figure(figsize=(12,6))

plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA50'], label='50-Day Moving Average')
plt.plot(df['MA200'], label='200-Day Moving Average')

plt.title("Google Stock Price with Moving Averages")
plt.xlabel("Year")
plt.ylabel("Stock Price")

plt.legend()

plt.savefig('images/moving_average.png')

plt.show()

# %%
df['Volatility'] = df['High'] - df['Low']

# %%
plt.figure(figsize=(12,6))

plt.plot(df['Volatility'])

plt.title("Daily Stock Price Volatility")
plt.xlabel("Year")
plt.ylabel("Price Difference")

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(df['Volume'])

plt.title("Trading Volume Over Time")
plt.xlabel("Year")
plt.ylabel("Volume")

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.heatmap(df.corr(), annot=True, cmap='coolwarm')

plt.title("Correlation Between Stock Features")

plt.show()

# %% [markdown]
# ## Key Insights
#
# 1. Google stock shows a strong long-term upward trend from 2004 to 2023.
#
# 2. Moving averages (50-day and 200-day) confirm a consistent long-term bullish trend.
#
# 3. Volatility increased significantly after 2018, indicating larger daily price swings.
#
# 4. Trading volume was highest during the early years after Google went public.
#
# 5. Strong correlation exists between Open, High, Low, Close, and Adjusted Close prices.
